# %%
#Downloading stock data from yahoo finance API
# !pip install yfinance
import yfinance as yf

# %%
pip show yfinance
# Out:
# Name: yfinance
# Version: 0.1.70
# Summary: Download market data from Yahoo! Finance API
# Home-page: https://github.com/ranaroussi/yfinance
# Author: Ran Aroussi
# Author-email: ran@aroussi.com
# License: Apache
# Location: /home/tony/anaconda3/lib/python3.8/site-packages
# Requires: lxml, multitasking, numpy, pandas, requests
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-05-23  3919.419922  3981.879883  3909.040039  3973.750000  3392770000
# 2022-05-24  3942.939941  3955.679932  3875.129883  3941.479980  3901640000
# 2022-05-25  3929.590088  3999.330078  3925.030029  3978.729980  4322190000
# 2022-05-26  3984.600098  4075.139893  3984.600098  4057.840088  3961940000
# 2022-05-27  4077.429932  4130.600098  4077.429932  4128.979980   833356762
#
# [18220 rows x 5 columns]

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-05-23  3919.419922  3981.879883  3909.040039  3973.750000  3392770000
# 2022-05-24  3942.939941  3955.679932  3875.129883  3941.479980  3901640000
# 2022-05-25  3929.590088  3999.330078  3925.030029  3978.729980  4322190000
# 2022-05-26  3984.600098  4075.139893  3984.600098  4057.840088  3961940000
# 2022-05-27  4077.429932  4130.600098  4077.429932  4128.979980   833356762
#
# [18220 rows x 5 columns]

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-05-23  3919.419922  3981.879883  3909.040039  3973.750000  3392770000
# 2022-05-24  3942.939941  3955.679932  3875.129883  3941.479980  3901640000
# 2022-05-25  3929.590088  3999.330078  3925.030029  3978.729980  4322190000
# 2022-05-26  3984.600098  4075.139893  3984.600098  4057.840088  3961940000
# 2022-05-27  4077.429932  4130.600098  4077.429932  4128.979980   833356762
#
# [18220 rows x 5 columns]

# %%
sp500["Tommorow"]= sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-05-23  3919.419922  3981.879883  3909.040039  3973.750000  3392770000
# 2022-05-24  3942.939941  3955.679932  3875.129883  3941.479980  3901640000
# 2022-05-25  3929.590088  3999.330078  3925.030029  3978.729980  4322190000
# 2022-05-26  3984.600098  4075.139893  3984.600098  4057.840088  3961940000
# 2022-05-27  4077.429932  4130.600098  4077.429932  4128.979980   833356762
#
#                Tommorow
# Date
# 1950-01-03    16.850000
# ...

# %%
sp500["Target"] = (sp500["Tommorow"]>sp500["Close"]).astype(int)
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-05-23  3919.419922  3981.879883  3909.040039  3973.750000  3392770000
# 2022-05-24  3942.939941  3955.679932  3875.129883  3941.479980  3901640000
# 2022-05-25  3929.590088  3999.330078  3925.030029  3978.729980  4322190000
# 2022-05-26  3984.600098  4075.139893  3984.600098  4057.840088  3961940000
# 2022-05-27  4077.429932  4130.600098  4077.429932  4128.979980   833356762
#
#                Tommorow  Target
# Date
# ...

# %%
sp500 = sp500.loc["1990-01-01":].copy()
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1990-01-02   353.399994   359.690002   351.980011   359.690002   162070000
# 1990-01-03   359.690002   360.589996   357.890015   358.760010   192330000
# 1990-01-04   358.760010   358.760010   352.890015   355.670013   177000000
# 1990-01-05   355.670013   355.670013   351.350006   352.200012   158530000
# 1990-01-08   352.200012   354.239990   350.540009   353.790009   140110000
# ...                 ...          ...          ...          ...         ...
# 2022-05-23  3919.419922  3981.879883  3909.040039  3973.750000  3392770000
# 2022-05-24  3942.939941  3955.679932  3875.129883  3941.479980  3901640000
# 2022-05-25  3929.590088  3999.330078  3925.030029  3978.729980  4322190000
# 2022-05-26  3984.600098  4075.139893  3984.600098  4057.840088  3961940000
# 2022-05-27  4077.429932  4130.600098  4077.429932  4128.979980   833356762
#
#                Tommorow  Target
# Date
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 100, min_samples_split = 100,random_state = 1)
train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Open","High","Low","Close","Volume"]
model.fit(train[predictors],train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score
preds = model.predict(test[predictors])

# %%
import pandas as pd
preds = pd.Series(preds, index = test.index)

# %%
precision_score(test["Target"],preds)
# Out:
# 0.4457831325301205

# %%
combined = pd.concat([test["Target"],preds],axis = 1)

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# The machine learning algorithm above is not great so we need to tweak some parameters as shown below.

# %%
#Building a back testing system.
def predict(train,test,predictors,model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds,index = test.index, name = "predictions")
    combined = pd.concat([test["Target"],preds],axis = 1)
    return combined

# %%
def backtest(data,model,predictors,start =2500,step = 250):
    all_predictions = []
    
    for i in range(start,data.shape[0],step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train,test,predictors,model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500,model,predictors)

# %%
predictions["predictions"].value_counts()
# Out:
# 0    3306
# 1    2360
# Name: predictions, dtype: int64

# %%
precision_score(predictions["Target"],predictions["predictions"])
# Out:
# 0.5317796610169492

# %%
predictions["predictions"].value_counts()/predictions.shape[0]
# Out:
# 0    0.58348
# 1    0.41652
# Name: predictions, dtype: float64

# %% [markdown]
# Looking at the result our machine learning alogorithm is doing worse than doing probability by hand

# %%
#Adding additional predictors to our model
horizons = [2,5,60,250,1000]

new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).sum()
    
    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"]/rolling_averages["Close"]
    
    trend_column = f"Trend_Column_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]
    new_predictors = [ratio_column,trend_column]

# %%
sp500.dropna()
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1993-12-14   465.730011   466.119995   462.459991   463.059998   275050000
# 1993-12-15   463.059998   463.690002   461.839996   461.839996   331770000
# 1993-12-16   461.859985   463.980011   461.859985   463.339996   284620000
# 1993-12-17   463.339996   466.380005   463.339996   466.380005   363750000
# 1993-12-20   466.380005   466.899994   465.529999   465.850006   255900000
# ...                 ...          ...          ...          ...         ...
# 2022-05-20  3927.760010  3943.419922  3810.320068  3901.360107  4278520000
# 2022-05-23  3919.419922  3981.879883  3909.040039  3973.750000  3392770000
# 2022-05-24  3942.939941  3955.679932  3875.129883  3941.479980  3901640000
# 2022-05-25  3929.590088  3999.330078  3925.030029  3978.729980  4322190000
# 2022-05-26  3984.600098  4075.139893  3984.600098  4057.840088  3961940000
#
# ...

# %%
model = RandomForestClassifier(n_estimators = 200, min_samples_split = 50,random_state = 1)

# %%
def predict(train,test,predictors,model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= 0.6] = 1
    preds[preds < 0.6] = 0
    preds = pd.Series(preds,index = test.index, name = "predictions")
    combined = pd.concat([test["Target"],preds],axis = 1)
    return combined

# %%
combined
# Out:
#             Target  0
# Date
# 2022-01-05       0  0
# 2022-01-06       0  1
# 2022-01-07       0  1
# 2022-01-10       1  1
# 2022-01-11       1  0
# ...            ... ..
# 2022-05-23       0  0
# 2022-05-24       1  0
# 2022-05-25       1  0
# 2022-05-26       1  1
# 2022-05-27       0  1
#
# [100 rows x 2 columns]

# %%
predictions = backtest(sp500,model,predictors)

# %%
predictions["predictions"].value_counts()
# Out:
# 0.0    4680
# 1.0     986
# Name: predictions, dtype: int64

# %%
precision_score(predictions["Target"],predictions["predictions"])
# Out:
# 0.526369168356998

# %% [markdown]
# The above results are still not satisfying but will continue to tweak my parameters.
